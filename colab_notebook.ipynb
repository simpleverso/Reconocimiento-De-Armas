# %%
import os
import re
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3943e923-c8b8-4d2b-9209-db696a9dbf14" name="files[]" multiple disabled />
#      <output id="result-3943e923-c8b8-4d2b-9209-db696a9dbf14">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving arma.jpg to arma (1).jpg

# %%
I1=cv2.imread('arma.jpg')
dim = (512, 512)
resized_image = cv2.resize(I1, (512, 512))
cv2.imwrite("arma.jpg", resized_image);
plt.imshow(resized_image)

# %%
resultado = !python predict_v1.py arma.jpg
caja = re.findall("\d+\.\d+", resultado[15]) #la informacion de la prediccion se guarda en resultado[15]
#caja # 5 valores - predicction_accuracy,x1,x2,y1,y2

# %%
im = np.array(resized_image, dtype=np.uint8)
fig,ax = plt.subplots(1)
ax.imshow(im)
rect = patches.Rectangle((float(caja[1])*512/1,float(caja[2])*512/1),float(caja[3])*512/1,float(caja[4])*512/1,linewidth=2,edgecolor='r',facecolor='none')
ax.add_patch(rect)
plt.show()
